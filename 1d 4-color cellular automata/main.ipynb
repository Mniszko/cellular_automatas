# %%
import matplotlib.pyplot as plt
import subprocess as sp
import random as rn
import numpy as np

# %%
for H in range(500):
    width = '500'
    #code = '0122101'
    code = ''

    for i in range(10):
        code += str(rn.randint(0,3))
    print(code)

    sp.run(['./test', width, code])

    lines = []
    with open('matrix.txt','r') as File:
        lines = File.readlines()
    File.close()

    fullbuff = []
    newbuff = []
    for i in lines:
        for k in i:
            if k != '\t' and k != '\n':
                newbuff.append(float(k))
        fullbuff.append(newbuff)
        newbuff = []
    fullbuff.pop(0)
    fullbuff.pop(len(fullbuff)-1)


    w = 7.195
    h = 3.841
    fig,ax = plt.subplots()
    fig.set_size_inches(w,h)
    im = ax.imshow(fullbuff,cmap='binary')
    ax.axis('off')
    plt.margins()

    fig.savefig('./graphics/'+code+'.png', bbox_inches='tight', pad_inches=0,dpi=1000)
# Out:
# 1133101001
# pulchra es humana
# 0231230233
# pulchra es humana
# 3130031210
# pulchra es humana
# 1010220332
# pulchra es humana
# 2100210110
# pulchra es humana
# 2302201212
# pulchra es humana
# 0100022012
# pulchra es humana
# 3311002312
# pulchra es humana
# 3031000032
# pulchra es humana
# 1321001311
# pulchra es humana
# 3210103213
# pulchra es humana
# 3111320301
# pulchra es humana
# 0233202002
# pulchra es humana
# 1310332103
# pulchra es humana
# 1301322321
# pulchra es humana
# 1013310320
# pulchra es humana
# 2232213303
# pulchra es humana
# 3032121103
# pulchra es humana
# 3132313120
# pulchra es humana
# 3300312002
# pulchra es humana
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_61565/3002030408.py in <module>
#      39
#      40
# ---> 41     fig.savefig('./graphics/'+code+'.png', bbox_inches='tight', pad_inches=0,dpi=1000)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3017                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3018
# -> 3019             self.canvas.print_figure(fname, **kwargs)
#    3020
#    3021     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~/.local/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2808
#    2809             self.patch.draw(renderer)
# -> 2810             mimage._draw_list_compositing_images(
#    2811                 renderer, self, artists, self.suppressComposite)
#    2812
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/lib/python3.10/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     644                 renderer.draw_image(gc, l, b, im, trans)
#     645         else:
# --> 646             im, l, b, trans = self.make_image(
#     647                 renderer, renderer.get_image_magnification())
#     648             if im is not None:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     954         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     955                 else self.figure.bbox)
# --> 956         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     957                                 magnification, unsampled=unsampled)
#     958
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     562             # (of int or float)
#     563             # or an RGBA array of re-sampled input
# --> 564             output = self.to_rgba(output, bytes=True, norm=False)
#     565             # output is now a correctly sized RGBA array of uint8
#     566
#
# ~/.local/lib/python3.10/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     454         if norm:
#     455             x = self.norm(x)
# --> 456         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     457         return rgba
#     458
#
# ~/.local/lib/python3.10/site-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     613             self._init()
#     614
# --> 615         mask_bad = X.mask if np.ma.is_masked(X) else np.isnan(X)  # Mask nan's.
#     616         xa = np.array(X, copy=True)
#     617         if not xa.dtype.isnative:
#
# ~/.local/lib/python3.10/site-packages/numpy/ma/core.py in __array_wrap__(self, obj, context)
#    3063             self._fill_value = _check_fill_value(None, self.dtype)
#    3064
# -> 3065     def __array_wrap__(self, obj, context=None):
#    3066         """
#    3067         Special hook for ufuncs.
#
# KeyboardInterrupt:

# %%
#randomizer:
f = open("inst.txt", "w")
for i in range(400):
    h = rn.randint(0,3)
    f.write(str(h))
    f.write('\n')
f.close()

# %%
#init single point in center

f = open('inst.txt','w')
rng = 140
inside = [0,1,0]
stp = len(inside)
for i in range(int(np.floor((rng-stp)/2))):
    f.write('0')
    f.write('\n')
for i in inside:
    f.write(str(i))
    f.write('\n')
for i in range(int(np.ceil((rng-stp)/2))):
    f.write('0')
    f.write('\n')
f.close()
